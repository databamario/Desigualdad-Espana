# %% [markdown]
# # 📋 Síntesis Ejecutiva: Desigualdad y Pobreza en España (2008-2023)
#
# ## Resumen Integrado del Estudio Completo
#
# ---
#
# Este notebook consolida las **conclusiones principales** de cuatro análisis complementarios:
#
# 1. **Análisis Nacional** (02_analisis_desigualdad_consolidado)
# 2. **Análisis Geográfico por CCAA** (05_analisis_geografico_ccaa_CONSOLIDADO)
# 3. **Análisis Sociodemográfico** (06_analisis_sociodemografico_CONSOLIDADO_V2)
# 4. **Comparativa Europea** (07_comparativa_europea_CONSOLIDADO)
#
# **Período de estudio:** 2008-2023 (16 años)
# **Fuentes:** INE (España) y Eurostat (UE27)
# **Enfoque:** Multidimensional (ingresos, territorio, demografía, contexto europeo)
#
# ---

# %% [markdown]
# ## 🎯 Hallazgos Principales
#
# ### 1️⃣ **LA PARADOJA NACIONAL: Gini Mejora, Pobres Empeoran**
#
# **Hallazgo crítico:**
# - ✅ Coeficiente de **Gini BAJÓ** (aparente mejora de desigualdad relativa)
# - ❌ **Renta real del decil D1 (10% más pobre) CAYÓ -6.96%** (2008-2023)
# - ❌ **AROPE (riesgo exclusión social) SUBIÓ +2.0pp** (26% población en 2023)
#
# **¿Cómo es posible?**
# Fenómeno de **"igualdad por empobrecimiento"**: Durante la crisis 2008-2012, los ricos perdieron más € en términos absolutos, lo que reduce la brecha relativa (Gini), pero los pobres perdieron **más en porcentaje** de sus ingresos, empeorando su vulnerabilidad real.
#
# **Conclusión:**
# El Gini es un indicador **engañoso** en contextos de empobrecimiento generalizado. El verdadero indicador de bienestar es **AROPE**, que captura vulnerabilidad multidimensional (renta + empleo + acceso a servicios).
#
# **Impacto inflación diferencial (2022):**
# Los pobres sufrieron **+0.74pp más inflación** que el promedio (gastan más en alimentos/energía, justo los rubros con mayor inflación).
#
# ---

# %% [markdown]
# ### 2️⃣ **DESIGUALDAD GEOGRÁFICA: El Patrón Norte-Sur**
#
# **Hallazgos territoriales:**
#
# **CCAA más desiguales (2023):**
# 1. Andalucía, Murcia, Extremadura, Castilla-La Mancha (predominio SUR)
# 2. Diferencia Norte-Sur es **estadísticamente significativa** y **creciente**
# 3. Coeficiente de Variación (CV%) entre CCAA **aumenta +0.31%/año** (p < 0.001)
#
# **Evolución temporal:**
# - ❌ **Divergencia regional confirmada**: Las CCAA NO convergen, se separan
# - ⚠️ **Problema estructural, no solo crisis**:
#   - Crisis 2008-2012: CV% empeora +0.37pp
#   - Recuperación 2012-2015: Solo revierte -0.03pp (insuficiente)
#   - Post-crisis 2015-2019: **Continúa empeorando** +0.09pp
#   - COVID 2019-2023: Acelera tendencia +0.07pp
#
# **Conclusión:**
# La desigualdad territorial tiene **raíces estructurales** (PIB per cápita, estructura laboral, políticas regionales), no es solo consecuencia de shocks económicos.
#
# ---

# %% [markdown]
# ### 3️⃣ **DESIGUALDAD SOCIODEMOGRÁFICA: Grupos Vulnerables**
#
# **Tasas AROPE por grupo (2023):**
#
# | Dimensión | Grupo Más Vulnerable | Tasa AROPE | Factor vs Nacional |
# |-----------|---------------------|------------|--------------------|
# | **Edad** | Menores de 16 años | **28.9%** | 1.1x |
# | **Tipo Hogar** | Monoparentales | **50.3%** | 1.9x (OUTLIER) |
# | **Situación Laboral** | Parados | **62.1%** | 2.4x |
# | **Sexo** | Mujeres | 27.2% | 1.08x |
#
# **Hallazgos críticos:**
#
# 1. **Hogares monoparentales**: Vulnerabilidad extrema (50.3% AROPE, 3x más que parejas con hijos)
# 2. **Personas paradas**: 62.1% en riesgo de exclusión (desempleo = pobreza casi garantizada)
# 3. **Menores de 16 años**: 28.9% AROPE (1 de cada 3 niños en riesgo)
# 4. **Trabajadores precarios**: 15.6% de ocupados en AROPE (trabajar NO garantiza salir de pobreza)
#
# **Interseccionalidad:**
# Las vulnerabilidades se **acumulan**: Una mujer monoparental parada tiene riesgo extremo de exclusión social.
#
# **Dimensión más estratificante:**
# **Situación laboral** (CV 67.2%) > Tipo hogar (CV 40.3%) > Edad (CV ~35%) > Sexo (CV ~8%)
#
# ---

# %% [markdown]
# ### 4️⃣ **POSICIÓN EUROPEA: España vs UE27**
#
# **Comparativa 2024:**
#
# | Indicador | España | UE27 | GAP | Veredicto |
# |-----------|--------|------|-----|----------|
# | **Gini** | 33-34 | 30-31 | **+3pp** | ⚠️ MÁS desigualdad |
# | **S80/S20** | 5.5-6.0 | 5.0-5.2 | **+0.5-0.8** | ⚠️ Extremos más separados |
# | **AROP (%)** | ~20% | 16-17% | **+3-4pp** | ⚠️ MÁS pobres |
# | **Brecha Pobreza** | ~28% | ~23% | **+5pp** | ⚠️ Pobres MÁS pobres |
# | **Impacto Redistributivo** | 3.4pp | 4.9pp | **-1.5pp** | ⚠️ Redistribuye MENOS |
#
# **Conclusión:**
# España tiene **peor desigualdad y pobreza** que la media UE27 en **TODOS** los indicadores.
#
# **Tendencia de convergencia:**
# - ✅ **Gini**: Converge en ~8 años (ritmo moderado)
# - ✅ **S80/S20**: Converge en ~7 años (extremos convergen rápido)
# - ⚠️ **Brecha pobreza**: Converge en ~15 años (lento)
# - ❌ **AROP**: Converge en ~26 años (MUY lento)
#
# **Hallazgo crítico:**
# S80/S20 mejora **2x más rápido** que Gini → **Clase media rezagada** (extremos convergen, pero el centro no).
#
# **Problema redistributivo doble:**
# 1. El **mercado laboral** español genera MÁS desigualdad (precariedad, dualidad)
# 2. El **Estado redistribuye MENOS** que la media UE27 (-1.5pp en 2024)
#
# ---

# %% [markdown]
# ## 🔑 Conclusiones Integradas
#
# ### **1. La desigualdad en España es un problema MULTIDIMENSIONAL y ESTRUCTURAL**
#
# - No es solo una cuestión de ingresos (Gini), sino de **vulnerabilidad real** (AROPE)
# - No es solo consecuencia de crisis económicas, sino de **factores estructurales persistentes**
# - Tiene dimensiones **territoriales** (Norte-Sur), **demográficas** (edad, hogar, empleo) y **comparativas** (España vs Europa)
#
# ### **2. Los indicadores tradicionales pueden ENGAÑAR**
#
# - El **Gini bajó** pero los **pobres empeoraron** → "Igualdad por empobrecimiento"
# - Trabajar **NO garantiza** salir de pobreza (15.6% ocupados en AROPE)
# - La **recuperación económica** NO revirtió el daño de la crisis (CV% regional sigue subiendo)
#
# ### **3. Existen grupos y territorios CRÍTICOS que requieren intervención focalizada**
#
# **Grupos prioritarios:**
# - Hogares monoparentales (50.3% AROPE)
# - Personas paradas (62.1% AROPE)
# - Menores de 16 años (28.9% AROPE)
# - Trabajadores precarios (15.6% ocupados en AROPE)
#
# **Territorios prioritarios:**
# - Andalucía, Murcia, Extremadura, Castilla-La Mancha (mayor desigualdad)
# - CCAA del Sur en general (brecha Norte-Sur creciente)
#
# ### **4. España converge con Europa, pero a velocidades DESIGUALES**
#
# - Los **extremos convergen rápido** (S80/S20: 7 años)
# - La **desigualdad general** converge moderado (Gini: 8 años)
# - La **pobreza absoluta** converge LENTO (AROP: 26 años)
# - La **clase media** está rezagada (brecha centro vs extremos)
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 📊 Métricas de Seguimiento (KPIs)
#
# Para evaluar progreso de políticas, se propone monitorear:
#
# ### **Indicadores Agregados (Nacional)**
# 1. **Tasa AROPE**: Objetivo reducir de 26.0% (2023) a <15% (meta UE 2030)
# 2. **Renta Real D1**: Objetivo recuperar nivel 2008 + crecimiento
# 3. **Ratio D10/D1**: Objetivo reducir brecha extremos
# 4. **Impacto Redistributivo**: Objetivo igualar media UE27 (4.9pp)
#
# ### **Indicadores Territoriales**
# 5. **CV% Gini entre CCAA**: Objetivo revertir divergencia (actualmente +0.31%/año)
# 6. **Brecha Norte-Sur**: Objetivo reducir diferencial
#
# ### **Indicadores Sociodemográficos**
# 7. **AROPE Monoparentales**: Objetivo reducir de 50.3% a <30%
# 8. **AROPE Menores**: Objetivo reducir de 28.9% a <15%
# 9. **AROPE Parados**: Objetivo reducir de 62.1% a <40%
# 10. **AROPE Ocupados**: Objetivo reducir de 15.6% a <8% ("working poor")
#
# ### **Indicadores Europeos**
# 11. **Convergencia GAP Gini vs UE27**: Objetivo cerrar en 8 años (según proyección)
# 12. **Convergencia GAP AROP vs UE27**: Objetivo acelerar (actualmente 26 años)
#
# **Frecuencia:** Actualización anual (publicación ECV del INE)
#
# **Responsabilidad:** Dashboard público interactivo (transparencia y accountability)
#
# ---

# %% [markdown]
# ## 🚧 Limitaciones del Estudio y Futuras Líneas de Investigación
#
# ### **Limitaciones de Datos**
#
# 1. **Series temporales incompletas:**
#    - AROPE por hogar: Faltan datos 2008-2012
#    - AROPE laboral: Faltan datos 2008-2013
#    - Carencia material por decil: No hay serie histórica completa
#
# 2. **Falta de datos poblacionales:**
#    - No se puede calcular **personas afectadas** por tipo de hogar/situación laboral
#    - Solo tenemos tasas (%), no volúmenes absolutos
#
# 3. **Falta de cruces multidimensionales:**
#    - No hay datos de **Edad × Hogar** (ej. menores en monoparentales)
#    - No hay datos de **Hogar × Empleo** (ej. monoparentales paradas)
#    - Limita análisis de **interseccionalidad**
#
# 4. **Inflación diferencial:**
#    - Solo analizada para 2022 (falta serie temporal completa por decil)
#    - Deflactación usa IPC general (infraestima pérdida poder adquisitivo pobres)
#
# ### **Futuras Líneas de Investigación**
#
# 1. **Análisis territorial sociodemográfico:**
#    - Cruzar dimensiones: AROPE por grupo × CCAA
#    - ¿Dónde concentrar políticas de infancia? ¿De empleo?
#    - ¿Heterogeneidad regional en brecha género?
#
# 2. **Análisis causal:**
#    - ¿Qué explica divergencia Norte-Sur? (PIB, estructura laboral, políticas)
#    - ¿Qué políticas regionales funcionan mejor? (benchmarking)
#    - ¿Impacto de reformas laborales en precariedad?
#
# 3. **Análisis dinámico:**
#    - Movilidad social intergeneracional (¿se hereda la pobreza?)
#    - Transiciones laborales (¿salir del paro = salir de AROPE?)
#    - Duración de episodios de pobreza (persistencia vs transitoria)
#
# 4. **Simulaciones de políticas:**
#    - ¿Impacto de subir IMV en AROPE?
#    - ¿Efecto de prestación universal por hijo en pobreza infantil?
#    - ¿Coste de cerrar GAP redistributivo con UE27?
#
# 5. **Comparativa europea granular:**
#    - España vs países similares (Italia, Portugal, Grecia)
#    - Aprender de países con baja desigualdad (Nórdicos)
#    - Análisis de políticas redistributivas efectivas
#
# ---

# %% [markdown]
# ## 📚 Resumen de Notebooks Analizados
#
# ### **Notebook 02: Análisis Nacional**
# - **Foco:** Evolución desigualdad España 2008-2023
# - **Indicadores:** Gini, S80/S20, AROPE, Renta por deciles, Inflación diferencial
# - **Hallazgo clave:** Paradoja Gini (baja) vs Pobres (empeoran)
#
# ### **Notebook 05: Análisis Geográfico CCAA**
# - **Foco:** Desigualdad territorial (¿DÓNDE está el problema?)
# - **Indicadores:** Gini y S80/S20 por CCAA, Convergencia/Divergencia
# - **Hallazgo clave:** Divergencia regional significativa (+0.31%/año CV), patrón Norte-Sur
#
# ### **Notebook 06: Análisis Sociodemográfico**
# - **Foco:** Desigualdad por edad, sexo, hogar, empleo (¿QUIÉNES son vulnerables?)
# - **Indicadores:** AROPE por grupo, Personas afectadas (cuando disponible)
# - **Hallazgo clave:** Monoparentales (50.3%), Parados (62.1%), Menores (28.9%)
#
# ### **Notebook 07: Comparativa Europea**
# - **Foco:** España vs UE27 (¿CÓMO estamos respecto a Europa?)
# - **Indicadores:** Gini, S80/S20, AROP, Brecha Pobreza, Impacto Redistributivo
# - **Hallazgo clave:** España peor en TODO, converge lento en AROP (26 años), redistribuye menos
#
# ---

# %% [markdown]
# ## ✅ Conclusión Final: Del Diagnóstico a la Acción
#
# ### **El Diagnóstico**
#
# La desigualdad y pobreza en España (2008-2023) es un problema **estructural, multidimensional y persistente**:
#
# 1. **No es solo desigualdad de ingresos** (Gini engaña) → Es vulnerabilidad multidimensional (AROPE)
# 2. **No es solo consecuencia de crisis** (recuperación no revierte daño) → Factores estructurales dominan
# 3. **No es homogénea** → Tiene dimensiones territoriales (Norte-Sur), demográficas (edad, hogar, empleo) y comparativas (España vs Europa)
# 4. **No se autocorrige** → Mercado dual + Estado débil = círculo vicioso
#
# ---
#
# ### **Las Causas Raíz Identificadas**
#
# El análisis revela **7 causas estructurales interconectadas**:
#
# 1. **Dualidad laboral** → 15.6% ocupados en AROPE (trabajar no garantiza vivir)
# 2. **Desempleo estructural** → 62.1% parados en AROPE (paro = pobreza casi segura)
# 3. **Divergencia territorial** → CV% regional crece +0.31%/año (Norte-Sur se alejan)
# 4. **Reproducción intergeneracional** → 28.9% menores en AROPE (niños pobres → adultos pobres)
# 5. **Monoparentalidad desprotegida** → 50.3% AROPE (outlier extremo)
# 6. **Brecha de género persistente** → +1.6pp AROPE mujeres (explotada en intersecciones)
# 7. **Estado redistributivo débil** → -1.5pp impacto vs UE27 (doble problema: mercado desigual + Estado pasivo)
#
# **Estas causas forman un círculo vicioso** que se retroalimenta y que el crecimiento económico por sí solo NO rompe (evidencia: post-2015 continúa divergencia).
#
# ---
#
# ### **La Estrategia de Solución**
#
# Basada en atacar **las causas raíz**, no los síntomas, con un plan integral en **4 niveles × 3 fases**:
#
# **NIVEL 1: Reformar Mercado Laboral**
# - Combatir dualidad (contrato único, inspección reforzada)
# - Salarios dignos (SMI gradual, in-work benefits)
# - Reducir paro estructural (SPE efectivo, formación continua, políticas activas territoriales)
#
# **NIVEL 2: Reducir Divergencia Territorial**
# - Política industrial regional selectiva (Sur: renovables, agrotech, logística)
# - Infraestructuras productivas (corredores, fibra, hubs logísticos)
# - Retener talento (becas arraigo, universidades-empresa)
#
# **NIVEL 3: Proteger Grupos Vulnerables**
# - Romper reproducción intergeneracional (prestación universal hijo, 0-3 años gratuito, comedor escolar)
# - Monoparentales (complemento IMV, garantía pensiones alimenticias, conciliación)
# - Parados (reforma desempleo, empleo-formación, emprendimiento cooperativo)
# - Igualdad género (transparencia salarial, corresponsabilidad cuidados, revalorizar sectores feminizados)
#
# **NIVEL 4: Fortalecer Redistribución**
# - Aumentar ingresos (IRPF progresivo, patrimonio armonizado, sucesiones, IS base amplia, combatir economía sumergida)
# - Optimizar gasto (IMV simplificado, servicios públicos reforzados)
# - Evitar austeridad crisis (estabilizadores automáticos, regla oro fiscal reformulada)
#
# ---
#
# ### **Implementación Gradual: Roadmap 2026-2035**
#
# **FASE 1 (2026-2027): Emergencias - 2 años**
# - Prestación hijo, IMV reformado, comedor escolar, garantía pensiones, IRPF nuevo tramo
# - **Coste:** 6,000M€/año | **Financiación:** Reforma fiscal +8,000M€ | **Balance:** Autofinanciable
#
# **FASE 2 (2028-2030): Reformas Estructurales - 3 años**
# - Mercado laboral, educación 0-3, SPE, política industrial, vivienda social
# - **Coste:** 15,000M€/año | **Financiación:** Patrimonio+Sucesiones+IS +12,000M€ | **Requiere:** Priorización gasto
#
# **FASE 3 (2031-2035): Convergencia UE - 5 años**
# - Presión fiscal 41% PIB, gasto social 25% PIB, AROPE <15%, CV% estable
# - **Financiación:** Economía circular (sostenibilidad recaudación)
#
# ---
#
# ### **Impacto Esperado**
#
# | Métrica | Actual (2023) | Objetivo (2035) | Cambio |
# |---------|---------------|-----------------|--------|
# | **AROPE Nacional** | 26.0% | <15% | -11pp |
# | **AROPE Menores** | 28.9% | <15% | -14pp |
# | **AROPE Monoparentales** | 50.3% | <30% | -20pp |
# | **AROPE Parados** | 62.1% | <40% | -22pp |
# | **AROPE Ocupados** | 15.6% | <8% | -8pp |
# | **CV% Regional** | Crece +0.31%/año | Decrece -0.15%/año | Reversión |
# | **Impacto Redistributivo** | 3.4pp | 4.9pp (=UE27) | +1.5pp |
# | **Presión Fiscal** | 37% PIB | 41% PIB (=UE27) | +4pp |
#
# **Beneficiarios directos:** >20 millones de personas (40% población)
# **Coste fiscal neto:** ~33,000M€/año (2.3% PIB)
# **Financiación:** 24,000M€ reforma fiscal + 6,000M€ crecimiento + 3,000M€ eficiencia
#
# ---
#
# ### **El Mensaje Final**
#
# **No basta diagnosticar.** Este estudio identifica:
# - ✅ **QUÉ** está mal (AROPE sube, pobres empeoran, territorios divergen, grupos vulnerables extremos)
# - ✅ **POR QUÉ** está mal (7 causas estructurales que forman círculo vicioso)
# - ✅ **CÓMO** solucionarlo (plan integral 4 niveles × 3 fases con costes, financiación e impactos)
#
# **Ahora depende de voluntad política y compromiso social.**
#
# La desigualdad en España NO es inevitable. Es el resultado de:
# - Mercados que **pueden** reformarse
# - Estados que **pueden** redistribuir más
# - Políticas que **pueden** focalizarse
# - Ciclos que **pueden** romperse
#
# **El objetivo es ambicioso pero factible:**
# Construir una España donde **trabajar garantice vivir dignamente**, **nacer en familia vulnerable no determine futuro**, y **vivir en el Sur no signifique menos oportunidades**.
#
# **Reducir AROPE de 26% a 15% en 10 años es posible** si atacamos las causas raíz con la misma rigurosidad con la que las hemos diagnosticado.
#
# ---
#
# **Fecha de elaboración:** Noviembre 2025
# **Equipo:** Análisis basado en datos INE y Eurostat (2008-2023)
# **Proyecto:** Desigualdad Social ETL - Síntesis Ejecutiva con Análisis Causal
# **Enfoque:** De la evidencia empírica a soluciones basadas en causas estructurales
#
# ---

# %% [markdown]
# ## 🔍 Análisis de Causas: ¿Por Qué Existe y Persiste la Desigualdad?
#
# ### **Marco Analítico: Causas Estructurales vs Coyunturales**
#
# Los datos revelan que la desigualdad en España tiene **raíces estructurales profundas**, no es solo consecuencia de crisis económicas temporales. Las causas se pueden clasificar en tres niveles:
#
# ---
#
# ### **NIVEL 1: CAUSAS ESTRUCTURALES DEL MERCADO LABORAL**
#
# **1.1 Dualidad y Precariedad Laboral**
#
# **Evidencia:**
# - 15.6% de trabajadores **ocupados** están en AROPE (trabajar NO garantiza salir de pobreza)
# - La situación laboral es la dimensión **más estratificante** (CV 67.2%)
# - Parados: 62.1% AROPE vs Ocupados: 15.6% AROPE (ratio 4x)
#
# **Causas subyacentes:**
# - **Mercado laboral dual**: Contratos indefinidos (protegidos) vs temporales (desprotegidos)
# - **Salarios bajos**: SMI insuficiente históricamente (mejorando desde 2019 pero daño acumulado)
# - **Parcialidad involuntaria**: Muchos empleos a tiempo parcial no por elección
# - **Sectores de baja productividad**: Concentración en servicios de bajo valor añadido (turismo, hostelería)
# - **Baja sindicalización**: Debilidad negociación colectiva (especialmente en pymes)
#
# **Mecanismo causal:**
# ```
# Dualidad laboral → Empleos precarios → Ingresos insuficientes →
# Working poor (15.6%) → Vulnerabilidad ante shocks → AROPE alto
# ```
#
# ---
#
# **1.2 Desempleo Estructural Elevado**
#
# **Evidencia:**
# - Parados: 62.1% AROPE (2 de cada 3 desempleados en riesgo extremo)
# - Divergencia regional correlaciona con tasas de paro (CCAA Sur > paro > desigualdad)
#
# **Causas subyacentes:**
# - **Desajuste cualificaciones**: Sistema educativo desconectado de necesidades mercado
# - **Rigideces estructurales**: Costes despido, regulaciones, movilidad geográfica baja
# - **Crisis de sectores tradicionales**: Construcción post-2008, industria deslocalizada
# - **Baja inversión I+D**: Falta empleos alto valor añadido
# - **Intermediación laboral débil**: Servicios empleo públicos poco efectivos
#
# **Mecanismo causal:**
# ```
# Paro estructural alto → Larga duración desempleo →
# Pérdida skills/desconexión → Exclusión permanente → AROPE 62.1%
# ```
#
# ---
#
# ### **NIVEL 2: CAUSAS ESTRUCTURALES TERRITORIALES**
#
# **2.1 Divergencia Norte-Sur Persistente**
#
# **Evidencia:**
# - CV% entre CCAA aumenta +0.31%/año (p < 0.001) → Divergencia significativa
# - Crisis 2008: +0.37pp | Recuperación: -0.03pp (insuficiente) | Post-crisis: +0.09pp (continúa)
# - TOP 8 más desiguales: 7 son del Sur (Andalucía, Murcia, Extremadura, C-LM)
#
# **Causas subyacentes:**
# - **PIB per cápita heterogéneo**: CCAA Norte > productividad > salarios > menor desigualdad
# - **Estructura productiva**:
#   - Norte: Industria, servicios avanzados, mayor valor añadido
#   - Sur: Agricultura, turismo estacional, construcción → empleos precarios
# - **Capital humano**: Norte > educación superior > empleos cualificados
# - **Infraestructuras**: Déficit histórico en Sur (aunque mejorando)
# - **Demografía**: Sur más población joven con mayor desempleo juvenil
# - **Instituciones**: Calidad gobierno regional varía (eficiencia gasto público)
#
# **Mecanismo causal:**
# ```
# Baja productividad regional → Empleos bajo valor añadido →
# Salarios bajos → Emigración cualificados → Círculo vicioso →
# Divergencia persistente (no revierte en recuperaciones)
# ```
#
# **Por qué es estructural (no solo crisis):**
# - Si fuera solo crisis → Recuperación 2012-2015 habría revertido divergencia
# - **Realidad**: Recuperación solo -0.03pp vs crisis +0.37pp (8% de reversión)
# - Post-crisis 2015-2019 **continúa divergiendo** +0.09pp
# - **Conclusión**: Hay factores permanentes (estructura productiva, capital humano, instituciones)
#
# ---
#
# ### **NIVEL 3: CAUSAS ESTRUCTURALES DEMOGRÁFICAS Y SOCIALES**
#
# **3.1 Vulnerabilidad Infantil: Reproducción Intergeneracional**
#
# **Evidencia:**
# - Menores 16 años: 28.9% AROPE (vs 13.9% mayores 65 años)
# - 1 de cada 3 niños en riesgo de pobreza o exclusión
#
# **Causas subyacentes:**
# - **Ingresos familiares bajos**: Familias con niños > gastos, mismos ingresos → pobreza
# - **Ausencia prestaciones universales por hijo**: España gasta menos en familia que UE27
# - **Servicios infancia insuficientes**: Escasez escuelas 0-3 años, coste alto → madre no trabaja
# - **Reproducción intergeneracional**: Niños pobres → peor educación → adultos pobres
#
# **Mecanismo causal:**
# ```
# Niño en hogar pobre → Menos recursos educativos →
# Peores resultados escolares → Menor formación →
# Empleo precario/paro adulto → Sus hijos pobres (CICLO)
# ```
#
# ---
#
# **3.2 Monoparentalidad: Vulnerabilidad Extrema**
#
# **Evidencia:**
# - Hogares monoparentales: **50.3% AROPE** (outlier estadístico)
# - 3x más que parejas con hijos (16.8%)
# - Mayoría mujeres (80%+)
#
# **Causas subyacentes:**
# - **Un solo ingreso**: Hogar depende de 1 sueldo (vs 2 en parejas)
# - **Dificultad conciliación**: Cuidado hijos sin pareja → menos horas trabajo → ingresos bajos
# - **Brecha género salarial**: Si madre, salario inferior + parcialidad involuntaria
# - **Pensiones alimenticias incumplidas**: ~30% no paga, Estado no garantiza
# - **Vivienda cara**: Coste % ingreso muy alto (prioridad tras cuidado)
# - **Red apoyo débil**: Sin familia extensa, sin servicios públicos suficientes
#
# **Mecanismo causal:**
# ```
# Monoparentalidad → 1 ingreso bajo + gastos altos (hijos+vivienda) →
# Imposibilidad trabajar jornada completa (cuidados) →
# Pobreza laboral o dependencia prestaciones → AROPE 50.3%
# ```
#
# ---
#
# **3.3 Brecha de Género (Moderada pero Persistente)**
#
# **Evidencia:**
# - Mujeres: 26.6% AROPE vs Hombres: 25.0% (+1.6pp)
# - CV Sexo solo 8% (baja estratificación agregada)
# - **PERO** brecha explota en intersecciones (mujeres monoparentales, paradas)
#
# **Causas subyacentes:**
# - **Brecha salarial**: ~20% menos salario mismo trabajo
# - **Segregación ocupacional**: Sectores feminizados = peor pagados (cuidados, limpieza)
# - **Parcialidad involuntaria**: Mujeres asumen cuidados → trabajos parciales
# - **Pensiones más bajas**: Carreras interrumpidas por maternidad
# - **"Penalización maternidad"**: Contratos inestables, promoción limitada
#
# **Mecanismo causal:**
# ```
# Roles género tradicionales → Mujeres asumen cuidados no remunerados →
# Parcialidad laboral → Salarios bajos →
# Pensiones bajas → Pobreza femenina (especialmente viudas/divorciadas)
# ```
#
# ---
#
# ### **NIVEL 4: CAUSAS INSTITUCIONALES (REDISTRIBUCIÓN DÉBIL)**
#
# **4.1 Estado Redistributivo Insuficiente**
#
# **Evidencia:**
# - España redistribuye **-1.5pp MENOS** que UE27 (Impacto Redistributivo: 3.4pp ES vs 4.9pp UE)
# - Gini final España: +3pp peor que UE27
# - **Doble problema**: Mercado MÁS desigual + Estado redistribuye MENOS
#
# **Causas subyacentes:**
#
# **Impuestos:**
# - **Presión fiscal baja**: 37% PIB (España) vs 41% PIB (UE27)
# - **Progresividad limitada**:
#   - IRPF: tipos máximos competitivos con fraude fiscal significativo
#   - Patrimonio: bonificaciones CCAA anulan impuesto (Madrid, Andalucía)
#   - Sucesiones: ídem (herencias grandes pagan poco)
# - **Economía sumergida**: ~18% PIB no tributa
#
# **Gasto social:**
# - **Bajo gasto familia**: 1.3% PIB (España) vs 2.3% (UE27) → niños desprotegidos
# - **Pensiones desiguales**: Sistema contributivo beneficia carreras largas (hombres, indefinidos)
# - **IMV tardío y limitado**:
#   - Implementado solo 2020 (UE tenía RMI desde décadas)
#   - Cobertura baja (~400k hogares de 1.8M potenciales)
#   - Burocracia excesiva, rechazos altos
# - **Servicios públicos débiles**:
#   - Educación 0-3: cobertura 20% (vs 50% Nórdicos)
#   - Dependencia: listas espera, prestaciones bajas
#
# **Mecanismo causal:**
# ```
# Presión fiscal baja → Gasto social limitado →
# Transferencias insuficientes + Servicios débiles →
# Pobreza post-redistribución alta → GAP vs UE27 persistente
# ```
#
# ---
#
# **4.2 Políticas Procíclicas (Austeridad en Crisis)**
#
# **Evidencia:**
# - AROPE creció más durante crisis (+8pp 2008-2013) que lo que bajó en recuperación (-6pp 2013-2023)
# - Renta D1 nunca recuperó nivel 2008 (-6.96% en 2023)
#
# **Causas subyacentes:**
# - **Austeridad 2010-2014**: Recortes gasto social en plena crisis
#   - Reducción empleados públicos
#   - Recorte prestaciones desempleo
#   - Copago sanitario
#   - Reducción inversión educación
# - **Consolidación fiscal prematura**: Prioridad déficit sobre desempleo
# - **Falta estabilizadores automáticos potentes**: RMI ausente hasta 2020
#
# **Mecanismo causal:**
# ```
# Crisis → Caída ingresos públicos → Austeridad (recortes) →
# Menor protección social → AROPE dispara +8pp →
# Recuperación débil (recortes permanentes) → AROPE no baja suficiente
# ```
#
# ---
#
# ### **SÍNTESIS CAUSAL: El Círculo Vicioso de la Desigualdad Española**
#
# ```
# ┌─────────────────────────────────────────────────────────────────────┐
# │                    CÍRCULO VICIOSO INTEGRADO                        │
# ├─────────────────────────────────────────────────────────────────────┤
# │                                                                     │
# │ 1. MERCADO DUAL → Trabajadores precarios (15.6% AROPE ocupados)    │
# │                                                                     │
# │ 2. DESEMPLEO ALTO → Especialmente jóvenes/Sur (62.1% parados AROPE)│
# │                                                                     │
# │ 3. DIVERGENCIA TERRITORIAL → Sur: baja productividad + paro alto   │
# │    → Emigración talento → Empeora estructura productiva (BUCLE)    │
# │                                                                     │
# │ 4. NIÑOS POBRES → Mala educación → Adultos precarios → REPRODUCE   │
# │                                                                     │
# │ 5. MONOPARENTALES DESPROTEGIDAS → Conciliación imposible →         │
# │    Parcialidad/paro → Pobreza extrema (50.3%)                      │
# │                                                                     │
# │ 6. ESTADO DÉBIL → Baja presión fiscal → Gasto social insuficiente →│
# │    No rompe círculos 1-5 → Redistribución -1.5pp bajo UE27         │
# │                                                                     │
# │ 7. AUSTERIDAD EN CRISIS → Recortes sociales → Agrava todo →        │
# │    Recuperación con daño permanente (D1 no recupera nivel 2008)    │
# │                                                                     │
# │ ➜ RESULTADO: Desigualdad ESTRUCTURAL que NO se autocorrige         │
# │   con crecimiento económico (post-2015 continúa divergencia)       │
# │                                                                     │
# └─────────────────────────────────────────────────────────────────────┘
# ```
#
# ---
#
# ### **Validación Empírica de Causas Estructurales**
#
# **Prueba 1: Test de Ciclos Económicos**
# - Si fueran causas coyunturales → Recuperación revertiría la crisis
# - **Realidad**: Recuperación 2012-2015 solo revierte 8% del daño de crisis 2008-2012
# - Post-crisis 2015-2019 **continúa empeorando** (+0.09pp CV regional)
# - **Conclusión**: Factores estructurales dominan
#
# **Prueba 2: Comparativa Europea**
# - Si fuera problema español único → Otros países no tendrían patrones similares
# - **Realidad**: España sistematicamente PEOR que UE27 en TODOS los indicadores
# - Diferencia es **PERSISTENTE** (converge lento: AROP 26 años)
# - **Conclusión**: España tiene problemas estructurales específicos (mercado dual, gasto social bajo)
#
# **Prueba 3: Interseccionalidad**
# - Si fueran factores aislados → No habría acumulación vulnerabilidades
# - **Realidad**: Mujer + monoparental + parada = vulnerabilidad EXTREMA
# - AROPE laboral (CV 67.2%) **explica más** que edad (35%) o sexo (8%)
# - **Conclusión**: Empleo es factor estructural dominante
#
# ---

# %% [markdown]
# ## 💊 Soluciones Basadas en Causas: Estrategia Integral de Intervención
#
# Basándonos en el análisis causal, las soluciones deben atacar **las raíces estructurales**, no solo los síntomas. Organizamos las intervenciones por nivel causal.
#
# ---
#
# ### **NIVEL 1: REFORMAR EL MERCADO LABORAL (Atacar Causa #1)**
#
# **Objetivo:** Reducir precariedad y dualidad laboral → Bajar AROPE ocupados de 15.6% a <8%
#
# ---
#
# #### **1.1 Combatir la Dualidad Laboral**
#
# **Causa identificada:** Mercado dual (indefinidos protegidos vs temporales desprotegidos) → 15.6% ocupados en AROPE
#
# **Soluciones:**
#
# **A) Contrato único con derechos crecientes** (modelo austriaco adaptado)
# - **Qué:** Eliminar tipos contractuales, 1 solo contrato con indemnización creciente por antigüedad
# - **Cómo:**
#   - Año 1: 8 días/año de indemnización
#   - Año 2-3: 15 días/año
#   - Año 4+: 20 días/año (como indefinidos actuales)
# - **Impacto esperado:** Reduce incentivo rotación, protección gradual, mercado más fluido
# - **Contrapartida:** Flexibilizar regulación despido objetivo (causas económicas)
#
# **B) Reforzar inspección trabajo y sanciones**
# - **Qué:** Combatir fraude (falsos autónomos, temporalidad encadenada)
# - **Cómo:**
#   - Duplicar plantilla inspección (actual: 1 inspector/11,000 trabajadores, objetivo UE: 1/10,000)
#   - Sanciones disuasorias (% facturación empresa, no cuantías fijas)
#   - Presunción laboralidad (invertir carga prueba en casos dudosos)
# - **Impacto esperado:** Reducir fraude temporal, mejorar protección
#
# **C) Promover negociación colectiva sectorial**
# - **Qué:** Ampliar cobertura convenios (actual ~70%, objetivo >85%)
# - **Cómo:**
#   - Extensión automática convenios sectoriales a todo el sector
#   - Facilitar negociación en pymes mediante representantes sectoriales
#   - Fortalecer sindicatos con recursos públicos condicionados a afiliación real
# - **Impacto esperado:** Compresión salarial, reducir "working poor"
#
# ---
#
# #### **1.2 Salarios Dignos: Continuar Subida SMI Gradual**
#
# **Causa identificada:** Salarios bajos → Insuficiente para vivir → Working poor
#
# **Soluciones:**
#
# **A) Mantener senda SMI hacia 60% salario mediano** (estándar UE)
# - **Situación actual:** SMI 2025 = ~€1,200/mes (14 pagas)
# - **Objetivo:** Alcanzar €1,400-1,500/mes en 2030 (ajustado inflación)
# - **Cómo:**
#   - Subidas graduales 3-4%/año (evitar shock empleo)
#   - Monitorear impacto en empleo (especialmente jóvenes, hostelería)
#   - Combinar con reducciones cuotas SS para pymes (compensar coste)
#
# **B) In-work benefits (complementos salariales)**
# - **Qué:** Transferencias públicas para trabajadores de bajos ingresos (modelo EITC EE.UU./UK)
# - **Cómo:**
#   - Complemento salarial vía IRPF (devolución impuestos)
#   - Requisitos: Trabajar mínimo 20h/semana, ingresos <umbral
#   - Cuantía: 100-200€/mes según renta y cargas familiares
# - **Impacto esperado:** Reducir AROPE ocupados sin afectar competitividad empresas
#
# ---
#
# #### **1.3 Reducir Desempleo Estructural**
#
# **Causa identificada:** Paro estructural alto + larga duración → 62.1% parados en AROPE
#
# **Soluciones:**
#
# **A) Reforma Servicios Públicos de Empleo (SPE)**
# - **Qué:** Convertir SPE en intermediadores efectivos (actual: burocracia pasiva)
# - **Cómo:**
#   - Ratio orientador/desempleado: 1/100 (actual ~1/300, objetivo Nórdicos 1/50)
#   - Planes individuales de empleo (formación + intermediación + seguimiento)
#   - Bonos formación individuales (trabajador elige centro, paga Estado)
#   - Coordinación con empresas (prospección activa vacantes)
# - **Impacto esperado:** Reducir duración media desempleo 30%
#
# **B) Formación continua y reciclaje**
# - **Qué:** Derecho universal formación a lo largo de la vida
# - **Cómo:**
#   - Cuenta individual formación: 500€/año acumulables (Estado + empresa)
#   - Permisos retribuidos formación (mínimo 5 días/año)
#   - Certificación skills (reconocimiento experiencia informal)
#   - Formación dual empresa-centro (modelo alemán adaptado)
# - **Impacto esperado:** Reducir desajuste skills, mejorar empleabilidad
#
# **C) Políticas activas focalizadas territorialmente**
# - **Qué:** Mayor inversión en CCAA alto desempleo (Sur)
# - **Cómo:**
#   - Bonificaciones contratación en CCAA >15% paro (SS, IRPF)
#   - Programas empleo público temporal (mantenimiento, cuidados, cultura)
#   - Inversión infraestructuras productivas (no solo obra civil)
# - **Impacto esperado:** Reducir brecha Norte-Sur en empleo
#
# ---
#
# ### **NIVEL 2: REDUCIR DIVERGENCIA TERRITORIAL (Atacar Causa #2)**
#
# **Objetivo:** Revertir divergencia regional (CV% baja de +0.31%/año a -0.15%/año)
#
# ---
#
# #### **2.1 Política Industrial Regional Selectiva**
#
# **Causa identificada:** Sur tiene estructura productiva bajo valor añadido → salarios bajos → desigualdad
#
# **Soluciones:**
#
# **A) Fondos desarrollo regional reforzados**
# - **Qué:** Inversión pública selectiva en sectores estratégicos regionales
# - **Cómo:**
#   - Identificar ventajas competitivas CCAA (cluster analysis)
#   - Financiar I+D+i aplicado (no genérico)
#   - Cofinanciación público-privada (50-50)
#   - Prioridad: Andalucía, Extremadura, Murcia, Castilla-La Mancha
# - **Ejemplos concretos:**
#   - Andalucía: Energías renovables, agrotech
#   - Murcia: Agroindustria tecnificada, logística
#   - Extremadura: Agroecología, turismo sostenible
# - **Impacto esperado:** Crear empleos alto valor añadido en Sur
#
# **B) Incentivos fiscales relocalizaciones empresariales**
# - **Qué:** Atraer empresas tecnológicas/industriales a CCAA rezagadas
# - **Cómo:**
#   - Bonificación 50% IS durante 5 años si se crea >100 empleos cualificados
#   - Subvenciones alquiler/compra suelo industrial
#   - Fast-track licencias/permisos
#   - Garantizar infraestructuras (fibra, carreteras)
# - **Impacto esperado:** Diversificar economía Sur, romper dependencia turismo/construcción
#
# ---
#
# #### **2.2 Conectividad e Infraestructuras**
#
# **Causa identificada:** Déficit histórico infraestructuras Sur → menor productividad
#
# **Soluciones:**
#
# **A) Completar corredores Mediterráneo y Atlántico**
# - **Qué:** Priorizar infraestructuras productivas (no solo AVE turístico)
# - **Cómo:**
#   - Corredor ferroviario mercancías Mediterráneo (conectar puertos+industria)
#   - Autovías pendientes (mejorar accesibilidad polígonos industriales)
#   - Fibra óptica 100% cobertura rural (teletrabajo, empresas digitales)
#
# **B) Hubs logísticos regionales**
# - **Qué:** Aprovechar posición geográfica (Sevilla, Murcia, Badajoz)
# - **Cómo:**
#   - Puertos secos, centros logísticos intermodales
#   - Zonas francas/especiales para atraer distribución
# - **Impacto esperado:** Crear empleos cualificados logística/comercio
#
# ---
#
# #### **2.3 Capital Humano: Retener y Atraer Talento**
#
# **Causa identificada:** Emigración jóvenes cualificados Sur → Norte/extranjero → empeora estructura
#
# **Soluciones:**
#
# **A) Becas retorno/arraigo**
# - **Qué:** Incentivar que titulados universitarios trabajen en su CCAA
# - **Cómo:**
#   - Condonación 50% préstamos estudios si trabajas 5 años en CCAA origen
#   - Ayudas vivienda jóvenes profesionales en ciudades medias Sur
#   - Deducciones IRPF autonómicas para <35 años (competencia fiscal inversa)
#
# **B) Universidades-empresa**
# - **Qué:** Conectar formación superior con tejido productivo regional
# - **Cómo:**
#   - Cátedras empresa en universidades Sur (I+D aplicado)
#   - Prácticas obligatorias remuneradas en empresas locales
#   - Startups universitarias con capital semilla público-regional
#
# ---
#
# ### **NIVEL 3: PROTEGER GRUPOS VULNERABLES (Atacar Causas #3)**
#
# **Objetivo:** Reducir AROPE grupos críticos (monoparentales 50.3%→30%, menores 28.9%→15%, parados 62.1%→40%)
#
# ---
#
# #### **3.1 Romper Reproducción Intergeneracional: Inversión en Infancia**
#
# **Causa identificada:** Niños pobres → mala educación → adultos pobres → CICLO
#
# **Soluciones:**
#
# **A) Prestación universal por hijo (0-18 años)**
# - **Qué:** Transferencia mensual por cada hijo, independiente de renta familiar
# - **Cómo:**
#   - Cuantía base: 100€/mes/hijo (1,200€/año)
#   - Suplemento renta baja (<60% mediana): +50€/mes
#   - Suplemento monoparental: +50€/mes
#   - **Ejemplo:** Monoparental 2 hijos renta baja = 400€/mes
# - **Coste:** ~8,000M€/año (0.6% PIB, actual gasto familia 1.3% → 1.9%, aún bajo UE 2.3%)
# - **Impacto esperado:** Reducir AROPE menores 28.9% → 18% (10pp)
#
# **B) Educación infantil 0-3 años universal y gratuita**
# - **Qué:** Garantizar plaza gratuita escuela infantil para TODOS (actual cobertura ~40%, objetivo 100%)
# - **Cómo:**
#   - Inversión pública: Construir/ampliar escuelas infantiles públicas
#   - Convenios privadas (plazas concertadas si cumplen ratios calidad)
#   - Personal cualificado (ratio 1 educador/8 niños)
# - **Coste:** ~4,000M€/año construcción + 2,000M€/año funcionamiento
# - **Impacto doble:**
#   1. Igualar oportunidades educativas (estimulación temprana)
#   2. Permitir madres monoparentales trabajar (conciliación)
#
# **C) Comedor escolar gratuito universal**
# - **Qué:** Garantizar al menos 1 comida nutritiva diaria a TODOS los menores
# - **Cómo:**
#   - Gratuidad universal primaria/secundaria (eliminar estigma "beca comedor")
#   - Menús saludables (nutricionistas, productos locales)
#   - Extensión vacaciones escolares (campamentos urbanos con comida)
# - **Coste:** ~1,500M€/año
# - **Impacto:** Nutrición asegurada (desarrollo cognitivo), apoyo familias vulnerables
#
# ---
#
# #### **3.2 Protección Específica Monoparentales**
#
# **Causa identificada:** 1 ingreso + gastos altos + conciliación imposible → 50.3% AROPE
#
# **Soluciones:**
#
# **A) Complemento monoparental IMV/Prestación hijo**
# - **Qué:** Reconocer sobrecarga monoparentales en sistema protección
# - **Cómo:**
#   - Suplemento IMV: +30% cuantía si hogar monoparental
#   - Prestación hijo: +50€/mes/hijo adicional (ya propuesto arriba)
#   - Prioridad acceso vivienda social (actualmente lista espera años)
#
# **B) Garantía pensiones alimenticias**
# - **Qué:** Estado garantiza pago cuando progenitor no paga
# - **Cómo:**
#   - Fondo público adelanta pensión (400€/mes/hijo estándar)
#   - Estado persigue deudor (embargo nómina/pensión, recargo)
#   - Modelo nórdico: "Anticipos pensión" (Suecia/Dinamarca)
# - **Impacto:** Asegurar ingresos estables, reducir pobreza monoparental
#
# **C) Flexibilidad laboral y conciliación**
# - **Qué:** Permitir compatibilizar empleo y cuidado hijos sin pareja
# - **Cómo:**
#   - Derecho reducción jornada sin pérdida proporcional salario (Estado compensa 50%)
#   - Teletrabajo preferente monoparentales
#   - Horarios escolares compatibles (ampliación hasta 17h con actividades)
#   - Permisos especiales enfermedad hijos (remunerados, sin límite razonable)
#
# ---
#
# #### **3.3 Parados: De Subsidio Pasivo a Activación Efectiva**
#
# **Causa identificada:** Paro = 62.1% AROPE (desempleo casi garantiza pobreza)
#
# **Soluciones:**
#
# **A) Reforma Prestación Desempleo**
# - **Qué:** Mayor cobertura + cuantías + duración, condicionado a activación
# - **Cómo:**
#   - Ampliar cobertura: 60% desempleados (actual ~50%)
#   - Cuantía: Mínimo 80% SMI (no bajar de umbral pobreza)
#   - Duración: Vincular a edad + carrera (mayores 50 = hasta 30 meses)
#   - Condicionalidad: Aceptar formación + búsqueda activa (SPE reforzado)
#
# **B) Programas Empleo-Formación**
# - **Qué:** Combinar subsidio + formación + experiencia laboral
# - **Cómo:**
#   - "Trabajo Garantizado": Estado empleador último recurso (6 meses, SMI)
#   - Sectores: Cuidados, mantenimiento, administración
#   - Requisito: Desempleo >12 meses
#   - Objetivo: Mantener hábito laboral, skills actualizadas, red contactos
#
# **C) Emprendimiento social/cooperativo**
# - **Qué:** Facilitar autoempleo colectivo en sectores estratégicos
# - **Cómo:**
#   - Capitalización prestación desempleo (pago único para iniciar negocio)
#   - Asesoría técnica pública gratuita (business plan, legal, fiscal)
#   - Microcréditos avalados ICO (hasta 50k€, sin aval personal)
#   - Prioridad: Cooperativas sociales (cuidados, renovables, economía circular)
#
# ---
#
# #### **3.4 Igualdad de Género: Medidas Transversales**
#
# **Causa identificada:** Brecha salarial + segregación + cuidados no remunerados → Mujeres más vulnerables
#
# **Soluciones:**
#
# **A) Transparencia salarial obligatoria**
# - **Qué:** Eliminar brecha salarial por discriminación
# - **Cómo:**
#   - Auditorías salariales obligatorias empresas >50 empleados
#   - Publicar bandas salariales por puesto (anonimizadas)
#   - Sanciones si brecha >5% sin justificación objetiva
#   - Inversión carga prueba: Empresa debe justificar diferencia
#
# **B) Corresponsabilidad cuidados**
# - **Qué:** Hombres asuman 50% cuidados (reducir parcialidad involuntaria mujeres)
# - **Cómo:**
#   - Permisos paternidad iguales e intransferibles (ya en vigor, mantener)
#   - Bonificaciones SS si padre coge reducción jornada
#   - Campañas normalización hombres cuidadores
#   - Servicios públicos cuidados (dependencia, escuelas infantiles) → liberar tiempo mujeres
#
# **C) Sectores feminizados: Revalorización**
# - **Qué:** Aumentar salarios sectores cuidados (enfermería, educación infantil, limpieza)
# - **Cómo:**
#   - Mejora convenios colectivos (presión pública)
#   - Subida suelos salariales sectores esenciales
#   - Profesionalización (titulaciones, carrera, promoción)
#
# ---
#
# ### **NIVEL 4: FORTALECER REDISTRIBUCIÓN (Atacar Causa #4)**
#
# **Objetivo:** Cerrar GAP redistributivo con UE27 (de -1.5pp a 0pp) → Impacto redistributivo 3.4pp→4.9pp
#
# ---
#
# #### **4.1 Aumentar Ingresos Públicos (Reforma Fiscal Progresiva)**
#
# **Causa identificada:** Presión fiscal baja (37% PIB vs 41% UE) → gasto social insuficiente
#
# **Soluciones:**
#
# **A) IRPF: Mayor progresividad efectiva**
# - **Qué:** Ricos paguen más (actualmente deducciones/fraude reducen tipos efectivos)
# - **Cómo:**
#   - Tramo adicional >300k€: 50% (actual máx. 47%)
#   - Reducir deducciones regresivas (vivienda habitual beneficia clases altas)
#   - Mínimo tributación efectiva: 15% sobre renta >100k€ (evitar elusión)
#   - Combatir fraude: Cruce datos (patrimonio, consumo, renta), presunción
#
# **B) Impuesto Patrimonio armonizado y efectivo**
# - **Qué:** Gravar grandes fortunas (actual: bonificaciones CCAA lo anulan)
# - **Cómo:**
#   - Estatal no transferible (evitar competencia fiscal CCAA)
#   - Exención: Primer millón (vivienda habitual)
#   - Tipos: 0.5% hasta 5M€, 1% hasta 10M€, 1.5% >10M€
#   - Anti-elusión: Incluir holdings, valoración mercado activos
#
# **C) Impuesto Sucesiones progresivo**
# - **Qué:** Gravar herencias grandes (reducir reproducción desigualdad intergeneracional)
# - **Cómo:**
#   - Exención: 250k€/heredero (proteger clase media)
#   - Tipos: 15% hasta 1M€, 25% hasta 5M€, 35% >5M€
#   - Estatal (evitar bonificaciones CCAA)
#
# **D) Impuesto Sociedades: Base más amplia**
# - **Qué:** Aumentar recaudación efectiva (muchas empresas pagan <10% efectivo)
# - **Cómo:**
#   - Mínimo tributación efectiva: 15% (estándar OCDE)
#   - Reducir deducciones genéricas, ampliar base
#   - Combatir planificación fiscal agresiva (SICAV, holdings)
#   - Tipo nominal: Mantener 25% (competitivo UE)
#
# **E) Economía sumergida: Reducción agresiva**
# - **Qué:** Incorporar 18% PIB no declarado (100,000M€) a tributación
# - **Cómo:**
#   - Pagos electrónicos obligatorios >500€ (trazabilidad)
#   - Límite efectivo 1,000€/transacción (actual 2,500€)
#   - Facturación electrónica obligatoria autónomos/pymes
#   - Inspección reforzada sectores críticos (hostelería, construcción, servicios personales)
#
# **Recaudación adicional estimada:** +25,000M€/año (+2% PIB) → De 37% a 39% presión fiscal
#
# ---
#
# #### **4.2 Optimizar Gasto Social (Más y Mejor)**
#
# **Causa identificada:** Gasto social bajo + mal focalizado → Redistribución débil
#
# **Soluciones:**
#
# **A) Reforma IMV: Mayor cobertura y simplicidad**
# - **Qué:** Alcanzar a todos los hogares bajo umbral pobreza (actual 25% cobertura, objetivo 70%)
# - **Cómo:**
#   - Simplificar requisitos (eliminar 3 años empadronamiento)
#   - Ventanilla única digital (solicitud online, respuesta 30 días)
#   - Presunción derecho: Si declaras renta baja, aprobación automática (inspección posterior)
#   - Cuantías: Actualizar anualmente con IPC
#   - Compatibilización empleo: No penalizar 100% ingreso laboral (deducir solo 50%)
#
# **B) Reforzar servicios públicos universales**
#
# **Sanidad:**
# - Eliminar copagos (regresivos, recaudan poco, dificultan acceso)
# - Reforzar atención primaria (ratio médico/paciente, listas espera)
# - Salud dental incluida (actualmente privada de facto)
#
# **Educación:**
# - Reducir ratio alumnos/aula (objetivo 20 en primaria, 25 en secundaria)
# - Becas comedor, libros, material 100% familias renta baja
# - Refuerzo escolar gratuito en centros vulnerables
# - Educación 0-3 universal (ya propuesto)
#
# **Vivienda:**
# - Construir 100k viviendas sociales/año (actual <20k)
# - Ayudas alquiler (complemento hasta cubrir 30% renta familiar)
# - Prohibición desahucios sin alternativa habitacional
#
# **Cuidados:**
# - Ley Dependencia: Eliminar listas espera (400k personas esperan)
# - Ampliar plazas residencias públicas, centros día
# - Profesionalizar sector (salarios dignos, formación)
#
# ---
#
# #### **4.3 Evitar Austeridad en Crisis (Estabilizadores Automáticos)**
#
# **Causa identificada:** Austeridad 2010-2014 agravó crisis social → AROPE +8pp
#
# **Soluciones:**
#
# **A) Regla de Oro Fiscal reformulada**
# - **Qué:** Proteger gasto social incluso con déficit alto
# - **Cómo:**
#   - Permitir déficit estructural >3% PIB en recesión (flexibilizar Pacto Estabilidad)
#   - Gasto social como inversión (capital humano), no gasto corriente
#   - Austeridad solo en crecimiento >2% PIB (acumular margen fiscal)
#
# **B) Estabilizadores automáticos potentes**
# - **Qué:** Gasto social que crece automáticamente en crisis sin aprobación parlamentaria
# - **Cómo:**
#   - Prestación desempleo extensión automática si tasa >12%
#   - IMV ampliación cobertura automática si AROPE >28%
#   - Fondo contingencia social (dotación 0.5% PIB/año en bonanza, uso en crisis)
#
# ---
#
# ### **ROADMAP DE IMPLEMENTACIÓN: Secuencia Temporal Óptima**
#
# Dada la complejidad y coste, se propone implementación **gradual en 3 fases**:
#
# ---
#
# #### **FASE 1 (2026-2027): Emergencias y Quick Wins - 2 años**
#
# **Prioridad:** Grupos más vulnerables + medidas alto impacto/bajo coste
#
# **Medidas:**
# 1. ✅ **Prestación universal por hijo**: 100€/mes (coste moderado, impacto alto niños)
# 2. ✅ **Reforma IMV**: Simplificar, ampliar cobertura (usar estructura existente)
# 3. ✅ **Comedor escolar gratuito universal**: Urgente (nutrición infantil)
# 4. ✅ **Garantía pensiones alimenticias**: Proteger monoparentales (coste bajo, 80% recuperable)
# 5. ✅ **Inspección trabajo reforzada**: Combatir fraude temporal (autofinanciable con multas)
# 6. ✅ **Reforma IRPF**: Nuevo tramo >300k€ (recaudación inmediata)
#
# **Financiación:** Reforma IRPF + economía sumergida → +8,000M€/año
# **Coste:** ~6,000M€/año (prestación hijo + comedor + IMV)
# **Balance:** Autofinanciable con reforma fiscal
#
# ---
#
# #### **FASE 2 (2028-2030): Reformas Estructurales - 3 años**
#
# **Prioridad:** Cambios profundos mercado laboral + servicios públicos
#
# **Medidas:**
# 1. ✅ **Reforma mercado laboral**: Contrato único (negociación social, gradual)
# 2. ✅ **Educación infantil 0-3 universal**: Construcción escuelas (4 años proceso)
# 3. ✅ **Reforma Servicios Empleo**: Contratar orientadores, digitalizar
# 4. ✅ **Política industrial regional**: Fondos desarrollo Sur
# 5. ✅ **Reforma Impuesto Sociedades**: Base más amplia (negociación UE)
# 6. ✅ **Vivienda social**: Plan 100k viviendas/año
#
# **Financiación:** Impuesto Patrimonio + Sucesiones + IS → +12,000M€/año
# **Coste:** ~15,000M€/año (0-3 años + vivienda + SPE)
# **Balance:** Requiere priorización gasto (reasignar de otros capítulos)
#
# ---
#
# #### **FASE 3 (2031-2035): Consolidación y Convergencia UE - 5 años**
#
# **Prioridad:** Alcanzar estándares UE27
#
# **Medidas:**
# 1. ✅ **Presión fiscal 41% PIB**: Completar armonización fiscal
# 2. ✅ **Gasto social 25% PIB** (actual 21%, UE27 ~24%)
# 3. ✅ **AROPE <15%**: Objetivo UE 2030 (con retraso, alcanzar 2035)
# 4. ✅ **Convergencia territorial**: CV% regional estable o decreciente
# 5. ✅ **Impacto redistributivo 4.9pp**: Igualar UE27
#
# **Financiación:** Economía circular (recaudación sostenida con reformas previas)
# **Evaluación:** Monitorear KPIs, ajustar políticas según evidencia
#
# ---
#
# ### **ESTIMACIÓN DE COSTES E IMPACTOS TOTALES**
#
# | Medida | Coste Anual (M€) | Beneficiarios | Impacto AROPE Esperado |
# |--------|------------------|---------------|------------------------|
# | Prestación universal hijo | 8,000 | 8M menores | -10pp AROPE menores (28.9%→18%) |
# | Educación 0-3 universal | 6,000 | 1.5M niños 0-3 | -3pp AROPE menores (indirecto) |
# | Comedor escolar gratuito | 1,500 | 4M alumnos | -2pp AROPE menores |
# | Reforma IMV (ampliación) | 3,000 | 1.8M hogares | -5pp AROPE general (26%→21%) |
# | Garantía pensiones aliment. | 500 | 300k monoparent. | -10pp AROPE monoparental (50%→40%) |
# | Complemento monoparental | 800 | 400k hogares | -5pp AROPE monoparental (40%→35%) |
# | Vivienda social (100k/año) | 5,000 | 400k hogares | -3pp AROPE general |
# | Reforma SPE + Políticas activas | 4,000 | 3M parados | -10pp AROPE parados (62%→52%) |
# | Ley Dependencia (listas espera) | 2,000 | 400k personas | -2pp AROPE mayores |
# | In-work benefits | 2,000 | 1M trabajadores | -5pp AROPE ocupados (15.6%→10%) |
# | **TOTAL GASTO ADICIONAL** | **~33,000M€** | **20M+ personas** | **AROPE 26%→15% (-11pp)** |
#
# **Financiación (recaudación adicional):**
# - Reforma IRPF (progresividad): +5,000M€
# - Patrimonio armonizado: +3,000M€
# - Sucesiones reforma: +2,000M€
# - IS base amplia: +4,000M€
# - Economía sumergida (-5pp): +10,000M€
# - **TOTAL INGRESOS**: +24,000M€
#
# **GAP:** 33,000 - 24,000 = **9,000M€/año déficit**
#
# **Solución GAP:**
# 1. Crecimiento económico: +1% PIB → +6,000M€ recaudación
# 2. Eficiencia gasto: Reasignar 3,000M€ (auditoría gasto ineficiente)
# 3. Deuda sostenible: 9,000M€ = 0.6% PIB déficit adicional (asumible si ratio deuda/PIB estabilizada)
#
# ---
#
# ### **GOBERNANZA Y EVALUACIÓN**
#
# **Responsabilidad Implementación:**
# - **Coordinación:** Vicepresidencia Derechos Sociales + Economía (comisión interministerial)
# - **Ejecución:** Ministerios sectoriales + CCAA (financiación condicionada)
# - **Seguimiento:** Oficina Independiente Evaluación Políticas Sociales (nueva, modelo UK)
#
# **Evaluación Rigurosa:**
# - **Ex-ante:** Simulaciones impacto con microdatos (INE, EPA, ECV)
# - **Pilotajes:** Testar políticas en CCAA/municipios antes generalizar
# - **Ex-post:** Evaluación cuantitativa impacto (diferencias-en-diferencias, RCTs cuando posible)
# - **Transparencia:** Publicar datos, metodología, resultados (accountability)
#
# **Ajustes Adaptativos:**
# - Revisión anual medidas según KPIs
# - Modificar cuantías/requisitos si evidencia muestra inefectividad
# - Eliminar políticas ineficaces, ampliar exitosas
#
# ---
#
# ### **CONCLUSIÓN: De Diagnóstico a Acción**
#
# Este plan de soluciones basado en causas estructurales identificadas:
#
# ✅ **Ataca las raíces**, no solo síntomas
# ✅ **Es integral**: Mercado + Estado + Territorios + Grupos
# ✅ **Es gradual**: 3 fases en 10 años (realista)
# ✅ **Es financiable**: Con reforma fiscal progresiva
# ✅ **Es ambicioso pero factible**: AROPE 26%→15% en 10 años
# ✅ **Está basado en evidencia**: Cada medida responde a causa identificada
# ✅ **Es evaluable**: KPIs claros, ajustes adaptativos
#
# **Objetivo final:** Convertir España en sociedad cohesionada con desigualdad comparable a media europea, donde **trabajar garantice vivir dignamente**, **nacer en familia vulnerable no determine futuro**, y **territorios converjan en oportunidades**.
#
# ---
